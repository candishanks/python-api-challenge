# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
data = pd.read_csv('city_weather_data_vacation.csv')

# %%
df = pd.DataFrame(data)
df
# Out:
#      Unnamed: 0                     0  Longitude  Latitude  Temperature  \
# 0             0                 Bluff   168.3333  -46.6000        13.33
# 1             1              Bagdarin   113.6000   54.4333         0.45
# 2             2       Lázaro Cárdenas  -102.2000   17.9583        22.58
# 3             3                Albany   -73.9662   42.6001         5.00
# 4             4               Rassvet    40.7500   46.8333         8.72
# ..          ...                   ...        ...       ...          ...
# 549         549    Provincia di Lecce    18.1667   40.2167        12.22
# 550         550              Oxapampa   -75.4017  -10.5775        14.63
# 551         551  City of Saint Peters   -90.6265   38.8003        10.00
# 552         552                Crixás   -49.9692  -14.5489        20.88
# 553         553                 Izhma    53.9113   65.0083        -3.86
#
#      Humidity  Cloudiness  Wind_Speed
# 0          70          87        1.79
# 1          30          87        8.05
# 2          73           0        1.83
# 3          80          95        0.94
# 4          73          96        2.24
# ..        ...         ...         ...
# 549        76           0        1.03
# 550        97          97        0.83
# 551        87          75        2.57
# 552        88          14        0.69
# 553        50          68        3.25
#
# [554 rows x 8 columns]

# %%
good_df = df.loc[df['Cloudiness'] <= 5]
good_df
# Out:
#      Unnamed: 0                   0  Longitude  Latitude  Temperature  \
# 2             2     Lázaro Cárdenas  -102.2000   17.9583        22.58
# 8             8              Castro   -50.0119  -24.7911        12.71
# 10           10      Port Elizabeth    25.5701  -33.9180        15.00
# 18           18             Iquique   -70.1431  -20.2208        18.00
# 20           20      Cabo San Lucas  -109.9124   22.8909        21.67
# ..          ...                 ...        ...       ...          ...
# 526         526             Nicşeni    26.6333   47.8667        10.00
# 531         531             College  -147.8028   64.8569         5.00
# 534         534             Merrill   -89.6835   45.1805         9.00
# 548         548             Sarakhs    61.1577   36.5449        26.00
# 549         549  Provincia di Lecce    18.1667   40.2167        12.22
#
#      Humidity  Cloudiness  Wind_Speed
# 2          73           0        1.83
# 8          97           4        1.17
# 10         77           0        1.03
# 18         72           0        1.54
# 20         55           2        5.64
# ..        ...         ...         ...
# 526        66           0        1.03
# 531        60           1        1.54
# 534        80           1        0.88
# 548        31           3        2.06
# 549        76           0        1.03
#
# [100 rows x 8 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
import json

# %%
cities = df['0']


for city in cities:
    target_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
    'address={0}&key={1}').format(city, g_key)

    geo_data = requests.get(target_url).json()

    print(geo_data)

    print(json.dumps(geo_data, indent=4, sort_keys=True))
# Out:
# {'results': [{'address_components': [{'long_name': 'Bluff', 'short_name': 'Bluff', 'types': ['locality', 'political']}, {'long_name': 'San Juan County', 'short_name': 'San Juan County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Utah', 'short_name': 'UT', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}], 'formatted_address': 'Bluff, UT, USA', 'geometry': {'bounds': {'northeast': {'lat': 37.3316241, 'lng': -109.484129}, 'southwest': {'lat': 37.2571699, 'lng': -109.647739}}, 'location': {'lat': 37.2844448, 'lng': -109.5517877}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 37.3316241, 'lng': -109.484129}, 'southwest': {'lat': 37.2571699, 'lng': -109.647739}}}, 'place_id': 'ChIJ64iscM7hOYcRMxPch26uyPs', 'types': ['locality', 'political']}], 'status': 'OK'}
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Bluff",
#                     "short_name": "Bluff",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "San Juan County",
#                     "short_name": "San Juan County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Utah",
#                     "short_name": "UT",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Bluff, UT, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 37.3316241,
#                         "lng": -109.484129
#                     },
#                     "southwest": {
#                         "lat": 37.2571699,
#                         "lng": -109.647739
#                     }
#                 },
#                 "location": {
#                     "lat": 37.2844448,
#                     "lng": -109.5517877
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.3316241,
#                         "lng": -109.484129
#                     },
#                     "southwest": {
#                         "lat": 37.2571699,
#                         "lng": -109.647739
#                     }
#                 }
#             },
#             "place_id": "ChIJ64iscM7hOYcRMxPch26uyPs",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# {'error_message': 'You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started', 'results': [], 'status': 'REQUEST_DENIED'}
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# {'results': [{'address_components': [{'long_name': 'Lázaro Cárdenas', 'short_name': 'Lázaro Cárdenas', 'types': ['locality', 'political']}, {'long_name': 'Baja California', 'short_name': 'B.C.', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Mexico', 'short_name': 'MX', 'types': ['country', 'political']}], 'formatted_address': 'Lázaro Cárdenas, Baja California, Mexico', 'geometry': {'bounds': {'northeast': {'lat': 30.5532695, 'lng': -115.9168024}, 'southwest': {'lat': 30.5141821, 'lng': -115.9553166}}, 'location': {'lat': 30.5252789, 'lng': -115.9330606}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 30.5532695, 'lng': -115.9168024}, 'southwest': {'lat': 30.5141821, 'lng': -115.9553166}}}, 'place_id': 'ChIJi1phurQPJoERBnWHGEuNAg8', 'types': ['locality', 'political']}, {'address_components': [{'long_name': '11161', 'short_name': '11161', 'types': ['street_number']}, {'long_name': 'Paseo de los Héroes', 'short_name': 'Paseo de los Héroes', 'types': ['route']}, {'long_name': 'Zona Urbana Rio Tijuana', 'short_name': 'Zona Urbana Rio Tijuana', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'Tijuana', 'short_name': 'Tijuana', 'types': ['locality', 'political']}, {'long_name': 'Baja California', 'short_name': 'B.C.', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Mexico', 'short_name': 'MX', 'types': ['country', 'political']}, {'long_name': '22010', 'short_name': '22010', 'types': ['postal_code']}], 'formatted_address': 'Prolongación, Paseo de los Héroes 11161, Zona Urbana Rio Tijuana, 22010 Tijuana, B.C., Mexico', 'geometry': {'location': {'lat': 32.5149275, 'lng': -117.004099}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 32.5162764802915, 'lng': -117.0027500197085}, 'southwest': {'lat': 32.5135785197085, 'lng': -117.0054479802915}}}, 'place_id': 'ChIJRVD4n6lJ2YARTw-fuwia_ig', 'types': ['establishment', 'point_of_interest', 'school', 'secondary_school']}, {'address_components': [{'long_name': 'Lázaro Cárdenas', 'short_name': 'Lázaro Cárdenas', 'types': ['locality', 'political']}, {'long_name': 'Chihuahua', 'short_name': 'Chih.', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Mexico', 'short_name': 'MX', 'types': ['country', 'political']}], 'formatted_address': 'Lázaro Cárdenas, Chih., Mexico', 'geometry': {'bounds': {'northeast': {'lat': 28.3995833, 'lng': -105.6097014}, 'southwest': {'lat': 28.3773509, 'lng': -105.6378438}}, 'location': {'lat': 28.3906054, 'lng': -105.6213516}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 28.3995833, 'lng': -105.6097014}, 'southwest': {'lat': 28.3773509, 'lng': -105.6378438}}}, 'place_id': 'ChIJMU6s6scF64YRtLTLpH7AeD8', 'types': ['locality', 'political']}, {'address_components': [{'long_name': 'Lázaro Cárdenas', 'short_name': 'Lázaro Cárdenas', 'types': ['locality', 'political']}, {'long_name': 'Baja California', 'short_name': 'B.C.', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Mexico', 'short_name': 'MX', 'types': ['country', 'political']}], 'formatted_address': 'Lázaro Cárdenas, B.C., Mexico', 'geometry': {'bounds': {'northeast': {'lat': 31.4123293, 'lng': -115.7129639}, 'southwest': {'lat': 31.3947294, 'lng': -115.7436636}}, 'location': {'lat': 31.4039014, 'lng': -115.7308336}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 31.4123293, 'lng': -115.7129639}, 'southwest': {'lat': 31.3947294, 'lng': -115.7436636}}}, 'place_id': 'ChIJsUoc-vF2KIERm7DebeyWYAA', 'types': ['locality', 'political']}, {'address_components': [{'long_name': 'Ejido Lázaro Cárdenas', 'short_name': 'Ej. Lázaro Cárdenas', 'types': ['locality', 'political']}, {'long_name': 'Baja California', 'short_name': 'B.C.', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Mexico', 'short_name': 'MX', 'types': ['country', 'political']}], 'formatted_address': 'Ej. Lázaro Cárdenas, B.C., Mexico', 'geometry': {'bounds' ...
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "L\u00e1zaro C\u00e1rdenas",
#                     "short_name": "L\u00e1zaro C\u00e1rdenas",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Baja California",
#                     "short_name": "B.C.",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Mexico",
#                     "short_name": "MX",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "L\u00e1zaro C\u00e1rdenas, Baja California, Mexico",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 30.5532695,
#                         "lng": -115.9168024
#                     },
#                     "southwest": {
#                         "lat": 30.5141821,
#                         "lng": -115.9553166
#                     }
#                 },
#                 "location": {
#                     "lat": 30.5252789,
#                     "lng": -115.9330606
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 30.5532695,
#                         "lng": -115.9168024
#                     },
#                     "southwest": {
#                         "lat": 30.5141821,
#                         "lng": -115.9553166
#                     }
#                 }
#             },
#             "place_id": "ChIJi1phurQPJoERBnWHGEuNAg8",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         },
#         {
#             "address_components": [
#                 {
#                     "long_name": "11161",
#                     "short_name": "11161",
#                     "types": [
#                         "street_number"
#                     ]
#                 },
#                 {
#                     "long_name": "Paseo de los H\u00e9roes",
#                     "short_name": "Paseo de los H\u00e9roes",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "Zona Urbana Rio Tijuana",
#                     "short_name": "Zona Urbana Rio Tijuana",
#                     "types": [
#                         "political",
#                         "sublocality",
#                         "sublocality_level_1"
#                     ]
#                 },
#                 {
#                     "long_name": "Tijuana",
#                     "short_name": "Tijuana",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Baja California",
#                     "short_name": "B.C.",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Mexico",
#                     "short_name": "MX",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "22010",
#                     "short_name": "22010",
#                     "types": [
#                         "postal_code"
#                     ]
#                 }
#             ],
#             "formatted_address": "Prolongaci\u00f3n, Paseo de los H\u00e9roes 11161, Zona Urbana Rio Tijuana, 22010 Tijuana, B.C., Mexico",
#             "geometry": {
#                 "location": {
#                     "lat": 32.5149275,
#                     "lng": -117.004099
#                 },
#                 "location_type": "ROOFTOP",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 32.5162764802915,
#                         "lng": -117.0027500197085
#                     },
#                     "southwest": {
#                         "lat": 32.5135785197085,
#                         "lng": -117.0054479802915
#                     }
#                 }
#             },
#             "place_id": "ChIJRVD4n6lJ2YARTw-fuwia_ig",
#             "types": [
#                 "establishment",
#                 "point_of_interest",
#                 "school",
#                 "secondary_school"
#             ]
#         },
#         {
#             "address_components": [
#                 {
#                     "long_name": "L\u00e1zaro C\u00e1rdenas",
#                     "short_name": "L\u00e1zaro C\u00e1rdenas",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Chihuahua",
#                     "short_name": "Chih.",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Mexico",
#                     "short_name": "MX",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "L\u00e1zaro C\u00e1rdenas, Chih., Mexico",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 28.3995833,
#                         "lng": -105.6097014
#                     },
#                     "southwest": {
#                         "lat": 28.3773509,
#                         "lng": -105.6378438
#                     }
#                 },
#                 "location": {
#                     "lat": 28.3906054,
#                     "lng": -105.6213516
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 28.3995833,
#                         "lng": -105.6097014
#                     },
#                     "southwest": {
#                         "lat": 28.3773509,
#                         "lng": -105.6378438
#                     }
#                 }
#             },
#             "place_id": "ChIJMU6s6scF64YRtLTLpH7AeD8",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         },
#         {
#             "address_components": [
#                 {
#                     "long_name": "L\u00e1zaro C\u00e1rdenas",
#                     "short_name": "L\u00e1zaro C\u00e1rdenas",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Baja California",
#                     "short_name": "B.C.",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Mexico",
#                     "short_name": "MX",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "L\u00e1zaro C\u00e1rdenas, B.C., Mexico",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 31.4123293,
#                         "lng": -115.7129639
#                     },
#                     "southwest": {
#                         "lat": 31.3947294,
#                         "lng": -115.7436636
#                     }
#                 },
#                 "location": {
#                     "lat": 31.4039014,
#                     "lng": -115.7308336
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 31.4123293,
#                         "lng": -115.7129639
#                     },
#                     "southwest": {
#                         "lat": 31.3947294,
#                         "lng": -115.7436636
#                     }
#                 }
#             },
#             "place_id": "ChIJsUoc-vF2KIERm7DebeyWYAA",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         },
#         {
#             "address_components": [
#                 {
#                     "long_name": "Ejido L\u00e1zaro C\u00e1rdenas",
#                     "short_name": "Ej. L\u00e1zaro C\u00e1rdenas",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Baja California",
#                     "short_name": "B.C.",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Mexico",
#                     "short_name": "MX",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Ej. L\u00e1zaro C\u00e1rdenas, B.C., Mexico",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 32.6147508,
#                         "lng": -115.0111562
#                     },
#                     "southwest": {
#                         "lat": 32.5992856,
#                         "lng": -115.0314182
#                     }
#                 },
#                 "location": {
#                     "lat": 32.6056014,
#                     "lng": -115.0192782
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 32.6147508,
#                         "lng": -115.0111562
#                     },
#                     "southwest": {
#                         "lat": 32.5992856,
#                         "lng": -115.0314182
#                     }
#                 }
#             },
#             "place_id": "ChIJfV0c5l4H14ARhqB_fovENYI",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         },
#         {
#             "address_components": [
#                 {
#                     "long_name": "Poblado L\u00e1zaro C\u00e1rdenas la 28",
#                     "short_name": "Pob L\u00e1zaro C\u00e1rdenas la 28",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Baja California",
#                     "short_name": "B.C.",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Mexico",
#                     "short_name": "MX",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Pob L\u00e1zaro C\u00e1rdenas la 28, B.C., Mexico",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 32.3800453,
#                         "lng": -115.0500242
#                     },
#                     "southwest": {
#                         "lat": 32.3583011,
#                         "lng": -115.0661155
#                     }
#                 },
#                 "location": {
#                     "lat": 32.3697045,
#                     "lng": -115.059696
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 32.3800453,
#                         "lng": -115.0500242
#                     },
#                     "southwest": {
#                         "lat": 32.3583011,
#                         "lng": -115.0661155
#                     }
#                 }
#             },
#             "place_id": "ChIJ9Q42uu-w14ARwXm_6tn7bzQ",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         },
#         {
#             "address_components": [
#                 {
#                     "long_name": "L\u00e1zaro C\u00e1rdenas",
#                     "short_name": "L\u00e1zaro C\u00e1rdenas",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Sonora",
#                     "short_name": "Son.",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Mexico",
#                     "short_name": "MX",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "L\u00e1zaro C\u00e1rdenas, Son., Mexico",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 27.2127723,
#                         "lng": -109.7281053
#                     },
#                     "southwest": {
#                         "lat": 27.208115,
#                         "lng": -109.7322325
#                     }
#                 },
#                 "location": {
#                     "lat": 27.2113888,
#                     "lng": -109.7305555
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 27.2127723,
#                         "lng": -109.7281053
#                     },
#                     "southwest": {
#                         "lat": 27.208115,
#                         "lng": -109.7322325
#                     }
#                 }
#             },
#             "place_id": "ChIJfdLLGhT9t4YRqgq10x2p2xc",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         },
#         {
#             "address_components": [
#                 {
#                     "long_name": "2345",
#                     "short_name": "2345",
#                     "types": [
#                         "street_number"
#                     ]
#                 },
#                 {
#                     "long_name": "South Millard Avenue",
#                     "short_name": "S Millard Ave",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "South Lawndale",
#                     "short_name": "South Lawndale",
#                     "types": [
#                         "neighborhood",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Chicago",
#                     "short_name": "Chicago",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Cook County",
#                     "short_name": "Cook County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Illinois",
#                     "short_name": "IL",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "60623",
#                     "short_name": "60623",
#                     "types": [
#                         "postal_code"
#                     ]
#                 }
#             ],
#             "formatted_address": "2345 S Millard Ave, Chicago, IL 60623, USA",
#             "geometry": {
#                 "location": {
#                     "lat": 41.8483589,
#                     "lng": -87.7157758
#                 },
#                 "location_type": "ROOFTOP",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 41.8497078802915,
#                         "lng": -87.7144268197085
#                     },
#                     "southwest": {
#                         "lat": 41.8470099197085,
#                         "lng": -87.71712478029151
#                     }
#                 }
#             },
#             "place_id": "ChIJCYlulWcyDogRNvG7ZlUdDRI",
#             "types": [
#                 "establishment",
#                 "point_of_interest",
#                 "primary_school",
#                 "school"
#             ]
#         },
#         {
#             "address_components": [
#                 {
#                     "long_name": "#1563",
#                     "short_name": "#1563",
#                     "types": [
#                         "street_number"
#                     ]
#                 },
#                 {
#                     "long_name": "Boulevard L\u00e1zaro C\u00e1rdenas",
#                     "short_name": "Blvrd L\u00e1zaro C\u00e1rdenas",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "Villafontana",
#                     "short_name": "Villafontana",
#                     "types": [
#                         "political",
#                         "sublocality",
#                         "sublocality_level_1"
#                     ]
#                 },
#                 {
#                     "long_name": "Mexicali",
#                     "short_name": "Mexicali",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Baja California",
#                     "short_name": "B.C.",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Mexico",
#                     "short_name": "MX",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "21180",
#                     "short_name": "21180",
#                     "types": [
#                         "postal_code"
#                     ]
#                 }
#             ],
#             "formatted_address": "Calzada General, Blvrd L\u00e1zaro C\u00e1rdenas #1563, Villafontana, 21180 Mexicali, B.C., Mexico",
#             "geometry": {
#                 "location": {
#                     "lat": 32.6241427,
#                     "lng": -115.5013674
#                 },
#                 "location_type": "ROOFTOP",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 32.6254916802915,
#                         "lng": -115.5000184197085
#                     },
#                     "southwest": {
#                         "lat": 32.6227937197085,
#                         "lng": -115.5027163802915
#                     }
#                 }
#             },
#             "place_id": "ChIJMfXstnVx14ARMN8Y8Uu71EE",
#             "types": [
#                 "establishment",
#                 "health",
#                 "point_of_interest"
#             ]
#         },
#         {
#             "address_components": [
#                 {
#                     "long_name": "Santa Clara Namiquipa",
#                     "short_name": "Santa Clara Namiquipa",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Chihuahua",
#                     "short_name": "Chih.",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Mexico",
#                     "short_name": "MX",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Santa Clara Namiquipa, Chih., Mexico",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 29.2963923,
#                         "lng": -106.9894123
#                     },
#                     "southwest": {
#                         "lat": 29.2750945,
#                         "lng": -107.0246459
#                     }
#                 },
#                 "location": {
#                     "lat": 29.2913855,
#                     "lng": -107.0155599
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 29.2963923,
#                         "lng": -106.9894123
#                     },
#                     "southwest": {
#                         "lat": 29.2750945,
#                         "lng": -107.0246459
#                     }
#                 }
#             },
#             "place_id": "ChIJvQgOdIA7woYRPTQsXIcmESk",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# {'results': [{'address_components': [{'long_name': 'Albany', 'short_name': 'Albany', 'types': ['locality', 'political']}, {'long_name': 'Albany County', 'short_name': 'Albany County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}], 'formatted_address': 'Albany, NY, USA', 'geometry': {'bounds': {'northeast': {'lat': 42.7223788, 'lng': -73.723263}, 'southwest': {'lat': 42.61379, 'lng': -73.898099}}, 'location': {'lat': 42.6525793, 'lng': -73.7562317}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 42.7223788, 'lng': -73.723263}, 'southwest': {'lat': 42.61379, 'lng': -73.898099}}}, 'place_id': 'ChIJS_tPzDQK3okRxCjnoBJjoeE', 'types': ['locality', 'political']}], 'status': 'OK'}
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Albany",
#                     "short_name": "Albany",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Albany County",
#                     "short_name": "Albany County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "New York",
#                     "short_name": "NY",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Albany, NY, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 42.7223788,
#                         "lng": -73.723263
#                     },
#                     "southwest": {
#                         "lat": 42.61379,
#                         "lng": -73.898099
#                     }
#                 },
#                 "location": {
#                     "lat": 42.6525793,
#                     "lng": -73.7562317
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 42.7223788,
#                         "lng": -73.723263
#                     },
#                     "southwest": {
#                         "lat": 42.61379,
#                         "lng": -73.898099
#                     }
#                 }
#             },
#             "place_id": "ChIJS_tPzDQK3okRxCjnoBJjoeE",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# {'results': [{'address_components': [{'long_name': '160', 'short_name': '160', 'types': ['street_number']}, {'long_name': 'Lexington Avenue', 'short_name': 'Lexington Ave', 'types': ['route']}, {'long_name': 'Manhattan', 'short_name': 'Manhattan', 'types': ['political', 'sublocality', 'sublocality_level_1']}, {'long_name': 'New York', 'short_name': 'New York', 'types': ['locality', 'political']}, {'long_name': 'New York County', 'short_name': 'New York County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'New York', 'short_name': 'NY', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '10016', 'short_name': '10016', 'types': ['postal_code']}], 'formatted_address': '160 Lexington Ave, New York, NY 10016, USA', 'geometry': {'location': {'lat': 40.7441358, 'lng': -73.98177299999999}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 40.74548478029149, 'lng': -73.98042401970848}, 'southwest': {'lat': 40.7427868197085, 'lng': -73.9831219802915}}}, 'place_id': 'ChIJTS9-FAhZwokRcbse7lr_jHA', 'plus_code': {'compound_code': 'P2V9+M7 New York, NY, USA', 'global_code': '87G8P2V9+M7'}, 'types': ['clothing_store', 'establishment', 'point_of_interest', 'store']}], 'status': 'OK'}
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "160",
#                     "short_name": "160",
#                     "types": [
#                         "street_number"
#                     ]
#                 },
#                 {
#                     "long_name": "Lexington Avenue",
#                     "short_name": "Lexington Ave",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "Manhattan",
#                     "short_name": "Manhattan",
#                     "types": [
#                         "political",
#                         "sublocality",
#                         "sublocality_level_1"
#                     ]
#                 },
#                 {
#                     "long_name": "New York",
#                     "short_name": "New York",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "New York County",
#                     "short_name": "New York County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "New York",
#                     "short_name": "NY",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "10016",
#                     "short_name": "10016",
#                     "types": [
#                         "postal_code"
#                     ]
#                 }
#             ],
#             "formatted_address": "160 Lexington Ave, New York, NY 10016, USA",
#             "geometry": {
#                 "location": {
#                     "lat": 40.7441358,
#                     "lng": -73.98177299999999
#                 },
#                 "location_type": "ROOFTOP",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 40.74548478029149,
#                         "lng": -73.98042401970848
#                     },
#                     "southwest": {
#                         "lat": 40.7427868197085,
#                         "lng": -73.9831219802915
#                     }
#                 }
#             },
#             "place_id": "ChIJTS9-FAhZwokRcbse7lr_jHA",
#             "plus_code": {
#                 "compound_code": "P2V9+M7 New York, NY, USA",
#                 "global_code": "87G8P2V9+M7"
#             },
#             "types": [
#                 "clothing_store",
#                 "establishment",
#                 "point_of_interest",
#                 "store"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# {'error_message': 'You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started', 'results': [], 'status': 'REQUEST_DENIED'}
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# {'error_message': 'You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started', 'results': [], 'status': 'REQUEST_DENIED'}
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# {'error_message': 'You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started', 'results': [], 'status': 'REQUEST_DENIED'}
# {
#     "error_message": "You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started",
#     "results": [],
#     "status": "REQUEST_DENIED"
# }
# {'results': [{'address_components': [{'long_name': 'The Castro', 'short_name': 'The Castro', 'types': ['neighborhood', 'political']}, {'long_name': 'San Francisco', 'short_name': 'SF', 'types': ['locality', 'political']}, {'long_name': 'San Francisco County', 'short_name': 'San Francisco County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'California', 'short_name': 'CA', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}], 'formatted_address': 'The Castro, San Francisco, CA, USA', 'geometry': {'bounds': {'northeast': {'lat': 37.7695956, 'lng': -122.4255558}, 'southwest': {'lat': 37.7554539, 'lng': -122.4467794}}, 'location': {'lat': 37.7609082, 'lng': -122.4350043}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 37.7695956, 'lng': -122.4255558}, 'southwest': {'lat': 37.7554539, 'lng': -122.4467794}}}, 'place_id': 'ChIJndQGNht-j4ARiXwy1QZmpsk', 'types': ['neighborhood', 'political']}], 'status': 'OK'}
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "The Castro",
#                     "short_name": "The Castro",
#                     "types": [
#                         "neighborhood",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "San Francisco",
#                     "short_name": "SF",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "San Francisco County",
#                     "short_name": "San Francisco County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "California",
#                     "short_name": "CA",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "The Castro, San Francisco, CA, USA",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 37.7695956,
#                         "lng": -122.4255558
#                     },
#                     "southwest": {
#                         "lat": 37.7554539,
#                         "lng": -122.4467794
#                     }
#                 },
#                 "location": {
#                     "lat": 37.7609082,
#                     "lng": -122.4350043
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 37.7695956,
#                         "lng": -122.4255558
#                     },
#                     "southwest": {
#                         "lat": 37.7554539,
#                         "lng": -122.4467794
#                     }
#                 }
#             },
#             "place_id": "ChIJndQGNht-j4ARiXwy1QZmpsk",
#             "types": [
#                 "neighborhood",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# {'results': [{'address_components': [{'long_name': 'Olinda', 'short_name': 'Olinda', 'types': ['locality', 'political']}, {'long_name': 'Olinda', 'short_name': 'Olinda', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Pernambuco', 'short_name': 'PE', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Brazil', 'short_name': 'BR', 'types': ['country', 'political']}], 'formatted_address': 'Olinda, PE, Brazil', 'geometry': {'bounds': {'northeast': {'lat': -7.954596199999999, 'lng': -34.8273273}, 'southwest': {'lat': -8.038466399999999, 'lng': -34.9167283}}, 'location': {'lat': -7.990714100000001, 'lng': -34.8416216}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': -7.954596199999999, 'lng': -34.8273273}, 'southwest': {'lat': -8.038466399999999, 'lng': -34.9167283}}}, 'place_id': 'ChIJKX_Ad_oXqwcRkddd8G-FjQc', 'types': ['locality', 'political']}], 'status': 'OK'}
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Olinda",
#                     "short_name": "Olinda",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Olinda",
#                     "short_name": "Olinda",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Pernambuco",
#                     "short_name": "PE",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Brazil",
#                     "short_name": "BR",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Olinda, PE, Brazil",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": -7.954596199999999,
#                         "lng": -34.8273273
#                     },
#                     "southwest": {
#                         "lat": -8.038466399999999,
#                         "lng": -34.9167283
#                     }
#                 },
#                 "location": {
#                     "lat": -7.990714100000001,
#                     "lng": -34.8416216
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": -7.954596199999999,
#                         "lng": -34.8273273
#                     },
#                     "southwest": {
#                         "lat": -8.038466399999999,
#                         "lng": -34.9167283
#                     }
#                 }
#             },
#             "place_id": "ChIJKX_Ad_oXqwcRkddd8G-FjQc",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# {'results': [{'address_components': [{'long_name': 'Gqeberha', 'short_name': 'Gqeberha', 'types': ['locality', 'political']}, {'long_name': 'Port Elizabeth', 'short_name': 'Port Elizabeth', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Eastern Cape', 'short_name': 'EC', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'South Africa', 'short_name': 'ZA', 'types': ['country', 'political']}], 'formatted_address': 'Gqeberha, South Africa', 'geometry': {'bounds': {'northeast': {'lat': -33.55308, 'lng': 25.86816}, 'southwest': {'lat': -34.050049, 'lng': 25.1922099}}, 'location': {'lat': -33.9608369, 'lng': 25.6022423}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': -33.55308, 'lng': 25.86816}, 'southwest': {'lat': -34.050049, 'lng': 25.1922099}}}, 'place_id': 'ChIJK9b_RQApex4RJkKJzTcj_YY', 'types': ['locality', 'political']}], 'status': 'OK'}
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Gqeberha",
#                     "short_name": "Gqeberha",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Port Elizabeth",
#                     "short_name": "Port Elizabeth",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Eastern Cape",
#                     "short_name": "EC",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "South Africa",
#                     "short_name": "ZA",
#                     "types": [
# ...
#                     "long_name": "Italy",
#                     "short_name": "IT",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "73100",
#                     "short_name": "73100",
#                     "types": [
#                         "postal_code"
#                     ]
#                 }
#             ],
#             "formatted_address": "73100 Lecce, Province of Lecce, Italy",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 40.3777911,
#                         "lng": 18.2285949
#                     },
#                     "southwest": {
#                         "lat": 40.3304703,
#                         "lng": 18.1199941
#                     }
#                 },
#                 "location": {
#                     "lat": 40.3515155,
#                     "lng": 18.1750161
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 40.3777911,
#                         "lng": 18.2285949
#                     },
#                     "southwest": {
#                         "lat": 40.3304703,
#                         "lng": 18.1199941
#                     }
#                 }
#             },
#             "place_id": "ChIJCREtL-QuRBMR8HezakxaW5s",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# {'results': [{'address_components': [{'long_name': 'Oxapampa', 'short_name': 'Oxapampa', 'types': ['locality', 'political']}, {'long_name': 'Oxapampa Province', 'short_name': 'Oxapampa Province', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Pasco', 'short_name': 'Pasco', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Peru', 'short_name': 'PE', 'types': ['country', 'political']}], 'formatted_address': 'Oxapampa, Peru', 'geometry': {'bounds': {'northeast': {'lat': -10.561819, 'lng': -75.38818359999999}, 'southwest': {'lat': -10.6050167, 'lng': -75.42509079999999}}, 'location': {'lat': -10.5750237, 'lng': -75.40001099999999}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': -10.561819, 'lng': -75.38818359999999}, 'southwest': {'lat': -10.6050167, 'lng': -75.42509079999999}}}, 'place_id': 'ChIJE8k16g3BCZERqj_CsykMXdE', 'types': ['locality', 'political']}], 'status': 'OK'}
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Oxapampa",
#                     "short_name": "Oxapampa",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Oxapampa Province",
#                     "short_name": "Oxapampa Province",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Pasco",
#                     "short_name": "Pasco",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Peru",
#                     "short_name": "PE",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 }
#             ],
#             "formatted_address": "Oxapampa, Peru",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": -10.561819,
#                         "lng": -75.38818359999999
#                     },
#                     "southwest": {
#                         "lat": -10.6050167,
#                         "lng": -75.42509079999999
#                     }
#                 },
#                 "location": {
#                     "lat": -10.5750237,
#                     "lng": -75.40001099999999
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": -10.561819,
#                         "lng": -75.38818359999999
#                     },
#                     "southwest": {
#                         "lat": -10.6050167,
#                         "lng": -75.42509079999999
#                     }
#                 }
#             },
#             "place_id": "ChIJE8k16g3BCZERqj_CsykMXdE",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# {'results': [{'address_components': [{'long_name': '1', 'short_name': '1', 'types': ['street_number']}, {'long_name': 'Saint Peters Centre Boulevard', 'short_name': 'St Peters Centre Blvd', 'types': ['route']}, {'long_name': 'St. Peters', 'short_name': 'St Peters', 'types': ['locality', 'political']}, {'long_name': 'Spencer Creek Township', 'short_name': 'Spencer Creek Township', 'types': ['administrative_area_level_3', 'political']}, {'long_name': 'St. Charles County', 'short_name': 'St Charles County', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Missouri', 'short_name': 'MO', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'United States', 'short_name': 'US', 'types': ['country', 'political']}, {'long_name': '63376', 'short_name': '63376', 'types': ['postal_code']}], 'formatted_address': '1 St Peters Centre Blvd, St Peters, MO 63376, USA', 'geometry': {'location': {'lat': 38.7916522, 'lng': -90.5960711}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 38.7930011802915, 'lng': -90.5947221197085}, 'southwest': {'lat': 38.7903032197085, 'lng': -90.59742008029151}}}, 'place_id': 'ChIJAQDAFyQo34cRxp5hwepWvnc', 'types': ['city_hall', 'establishment', 'local_government_office', 'point_of_interest']}], 'status': 'OK'}
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "1",
#                     "short_name": "1",
#                     "types": [
#                         "street_number"
#                     ]
#                 },
#                 {
#                     "long_name": "Saint Peters Centre Boulevard",
#                     "short_name": "St Peters Centre Blvd",
#                     "types": [
#                         "route"
#                     ]
#                 },
#                 {
#                     "long_name": "St. Peters",
#                     "short_name": "St Peters",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Spencer Creek Township",
#                     "short_name": "Spencer Creek Township",
#                     "types": [
#                         "administrative_area_level_3",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "St. Charles County",
#                     "short_name": "St Charles County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Missouri",
#                     "short_name": "MO",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "United States",
#                     "short_name": "US",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "63376",
#                     "short_name": "63376",
#                     "types": [
#                         "postal_code"
#                     ]
#                 }
#             ],
#             "formatted_address": "1 St Peters Centre Blvd, St Peters, MO 63376, USA",
#             "geometry": {
#                 "location": {
#                     "lat": 38.7916522,
#                     "lng": -90.5960711
#                 },
#                 "location_type": "ROOFTOP",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 38.7930011802915,
#                         "lng": -90.5947221197085
#                     },
#                     "southwest": {
#                         "lat": 38.7903032197085,
#                         "lng": -90.59742008029151
#                     }
#                 }
#             },
#             "place_id": "ChIJAQDAFyQo34cRxp5hwepWvnc",
#             "types": [
#                 "city_hall",
#                 "establishment",
#                 "local_government_office",
#                 "point_of_interest"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# {'results': [{'address_components': [{'long_name': 'Crixás', 'short_name': 'Crixás', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'State of Goiás', 'short_name': 'GO', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Brazil', 'short_name': 'BR', 'types': ['country', 'political']}, {'long_name': '76510-000', 'short_name': '76510-000', 'types': ['postal_code']}], 'formatted_address': 'Crixás - State of Goiás, 76510-000, Brazil', 'geometry': {'bounds': {'northeast': {'lat': -14.1255726, 'lng': -49.69400479999999}, 'southwest': {'lat': -15.1363838, 'lng': -50.4485712}}, 'location': {'lat': -14.5330896, 'lng': -49.960644}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': -14.1255726, 'lng': -49.69400479999999}, 'southwest': {'lat': -15.1363838, 'lng': -50.4485712}}}, 'place_id': 'ChIJEYXkgMV-QpMR6v3Rqd8FplE', 'types': ['administrative_area_level_2', 'political']}], 'status': 'OK'}
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Crix\u00e1s",
#                     "short_name": "Crix\u00e1s",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "State of Goi\u00e1s",
#                     "short_name": "GO",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Brazil",
#                     "short_name": "BR",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "76510-000",
#                     "short_name": "76510-000",
#                     "types": [
#                         "postal_code"
#                     ]
#                 }
#             ],
#             "formatted_address": "Crix\u00e1s - State of Goi\u00e1s, 76510-000, Brazil",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": -14.1255726,
#                         "lng": -49.69400479999999
#                     },
#                     "southwest": {
#                         "lat": -15.1363838,
#                         "lng": -50.4485712
#                     }
#                 },
#                 "location": {
#                     "lat": -14.5330896,
#                     "lng": -49.960644
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": -14.1255726,
#                         "lng": -49.69400479999999
#                     },
#                     "southwest": {
#                         "lat": -15.1363838,
#                         "lng": -50.4485712
#                     }
#                 }
#             },
#             "place_id": "ChIJEYXkgMV-QpMR6v3Rqd8FplE",
#             "types": [
#                 "administrative_area_level_2",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }
# {'results': [{'address_components': [{'long_name': 'Izhma', 'short_name': 'Izhma', 'types': ['locality', 'political']}, {'long_name': 'Izhemsky District', 'short_name': 'Izhemsky District', 'types': ['administrative_area_level_2', 'political']}, {'long_name': 'Komi Republic', 'short_name': 'Komi Republic', 'types': ['administrative_area_level_1', 'political']}, {'long_name': 'Russia', 'short_name': 'RU', 'types': ['country', 'political']}, {'long_name': '169460', 'short_name': '169460', 'types': ['postal_code']}], 'formatted_address': 'Izhma, Komi Republic, Russia, 169460', 'geometry': {'bounds': {'northeast': {'lat': 65.02467399999999, 'lng': 53.9427142}, 'southwest': {'lat': 64.9988149, 'lng': 53.88564100000001}}, 'location': {'lat': 65.00700650000002, 'lng': 53.9197413}, 'location_type': 'APPROXIMATE', 'viewport': {'northeast': {'lat': 65.02467399999999, 'lng': 53.9427142}, 'southwest': {'lat': 64.9988149, 'lng': 53.88564100000001}}}, 'place_id': 'ChIJiY98PBjBc0QR-q9M2p17UWo', 'types': ['locality', 'political']}], 'status': 'OK'}
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Izhma",
#                     "short_name": "Izhma",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Izhemsky District",
#                     "short_name": "Izhemsky District",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Komi Republic",
#                     "short_name": "Komi Republic",
#                     "types": [
#                         "administrative_area_level_1",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Russia",
#                     "short_name": "RU",
#                     "types": [
#                         "country",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "169460",
#                     "short_name": "169460",
#                     "types": [
#                         "postal_code"
#                     ]
#                 }
#             ],
#             "formatted_address": "Izhma, Komi Republic, Russia, 169460",
#             "geometry": {
#                 "bounds": {
#                     "northeast": {
#                         "lat": 65.02467399999999,
#                         "lng": 53.9427142
#                     },
#                     "southwest": {
#                         "lat": 64.9988149,
#                         "lng": 53.88564100000001
#                     }
#                 },
#                 "location": {
#                     "lat": 65.00700650000002,
#                     "lng": 53.9197413
#                 },
#                 "location_type": "APPROXIMATE",
#                 "viewport": {
#                     "northeast": {
#                         "lat": 65.02467399999999,
#                         "lng": 53.9427142
#                     },
#                     "southwest": {
#                         "lat": 64.9988149,
#                         "lng": 53.88564100000001
#                     }
#                 }
#             },
#             "place_id": "ChIJiY98PBjBc0QR-q9M2p17UWo",
#             "types": [
#                 "locality",
#                 "political"
#             ]
#         }
#     ],
#     "status": "OK"
# }

# %%
for city in cities: 
    geo_data
   
    try: 
        city_name.append(response_json['name'])
        lng.append(response_json['coord']['lon'])
        lat.append(response_json['coord']['lat'])
        temp.append(response_json['main']['temp_max'])
        humidity.append(response_json['main']['humidity'])
        cloudiness.append(response_json['clouds']['all'])
        wind_speed.append(response_json['wind']['speed'])
        print(f"{city} found!")
            
    except:
        pass

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map


# Display figure
